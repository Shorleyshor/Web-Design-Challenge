# %%
import pandas as pd

# %%
# Read the csv file in
df = pd.read_csv('Resources/cities.csv')

# %%
# Save to file
df.to_html('csvtodata.html', index=False)

# %%
# Printing data
data = df.to_html()
